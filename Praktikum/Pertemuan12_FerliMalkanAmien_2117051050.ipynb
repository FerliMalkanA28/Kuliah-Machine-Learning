# %% [markdown]
# Nama : Ferli Malkan Amien <br>
# NPM  : 2117051050 <br>
# Kelas: C <br>
# Link : https://colab.research.google.com/drive/19LDlC33_S8Zhv0c4mg-TVZDqPZMrEo9_?usp=sharing

# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ## Library

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rahmantaufik27/dataset/main/study/churn_bank_customer.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# ## Preprocessing

# %%
# split data menjadi data X dan Y (target/dependent variabel)
# edata Exited digunakan sebagai data Y
Y = df.iloc[:, -1].values
# selaind data Exited, RowNumber, CustomerID, Surname, digunaan sebagai data X
X = df.iloc[:, 3:-1].values
print(Y)
print(X)
# Out:
# [1 0 1 ... 1 1 0]
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
# untuk data X, kita ubah terlebih dahulu data categorical (Geograpy, Gender) menjadi number
le = LabelEncoder()
X[:, 2] = np.array(le.fit_transform(X[:,2]))
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder = 'passthrough')
X = np.array(ct.fit_transform(X))
print(X)
# Out:
# [[1.0 0.0 0.0 ... 1 1 101348.88]
#  [0.0 0.0 1.0 ... 0 1 112542.58]
#  [1.0 0.0 0.0 ... 1 0 113931.57]
#  ...
#  [1.0 0.0 0.0 ... 0 1 42085.58]
#  [0.0 1.0 0.0 ... 1 0 92888.52]
#  [1.0 0.0 0.0 ... 1 0 38190.78]]

# %%
# split data otomatis/random menggunakan fungsi library tertentu
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# scaling data
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Modeling

# %%
# buat fungsi untuk pemodelan ANN
model_ann = tf.keras.Sequential([
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=6, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# compile model ann
model_ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting data dengan model ann yang dibuat
model_ann.fit(X_train, Y_train, batch_size = 32, epochs = 100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 4s 2ms/step - loss: 0.5322 - accuracy: 0.7890
# Epoch 2/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.7962
# Epoch 3/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.7997
# Epoch 4/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4351 - accuracy: 0.8054
# Epoch 5/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.8071
# Epoch 6/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.8101
# Epoch 7/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.8166
# Epoch 8/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8177
# Epoch 9/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4027 - accuracy: 0.8191
# Epoch 10/100
# ...

# %% [markdown]
# *   Pada proses modeling di atas kita dapat melihat akurasi data training, akurasi tersebut bukanlah evaluasi yang dicari
# *   akurasi akhir yang perlu dicari harus mewakili data not-before-seen"/"not-trained" yang mana contohnya di bawah ini

# %% [markdown]
# ## Evaluation

# %%
model_ann.evaluate(X_test, Y_test, batch_size = 8)
# Out:
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3357 - accuracy: 0.8575
# [0.33570393919944763, 0.8575000166893005]

# %%
# cobe prediksi suatu data
print(model_ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])) > 0.5)
# Out:
# 1/1 [==============================] - 0s 96ms/step
# [[False]]
